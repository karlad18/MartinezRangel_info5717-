# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [18, 6, 1]
plt.plot(x, y)
plt.plot(x, z)
plt.title("Assignment plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
alm_hardware = pd.read_csv('alm_hardware.csv')

# %%
alm_hardware
# Out:
#            Asset tag Model category  \
# 0            4NS6SY2      Computers
# 1         VF00013017      Computers
# 2         VFNA010027      Computers
# 3         VFNA016451      Computers
# 4         VFNA016519      Computers
# ..               ...            ...
# 98        VFNA020142      Computers
# 99        VFNA020143      Computers
# 100       VFNA020144      Computers
# 101       VFNA020179      Computers
# 102  VFSNA0000000532      Computers
#
#                                           Display name  Assigned to  \
# 0             4NS6SY2 - Dell Precision 5820 (Graphics)          NaN
# 1        VF00013017 - Apple MacBook Pro MacBookPro15,1          NaN
# 2           VFNA010027 - Dell XPS (Notebook) 13 (9365)          NaN
# 3                      VFNA016451 - Dell Latitude 7490          NaN
# 4                      VFNA016519 - Dell Latitude 7490          NaN
# ..                                                 ...          ...
# ...

# %%
type(alm_hardware)
# Out:
# pandas.core.frame.DataFrame

# %%
type(alm_hardware.State)
# Out:
# pandas.core.series.Series

# %%
plt.plot(alm_hardware.State, alm_hardware.Cost, 'o')
plt.plot(alm_hardware.State, alm_hardware.Substate)
plt.show()

# %%
data = pd.read_csv('assignment_property.csv')

# %%
data
# Out:
#             PID LEGAL_TYPE         FOLIO  LAND_COORDINATE   ZONE_NAME  \
# 0   030-712-831       LAND  6.131190e+11         61311906       RM-5A
# 1   003-614-468     STRATA  6.841650e+11         68416507        RM-3
# 2   029-610-885     STRATA  6.401230e+11         64012298        C-2B
# 3   030-764-386     STRATA  6.541920e+11         65419193  CD-1 (591)
# 4   030-764-637     STRATA  6.541920e+11         65419193  CD-1 (591)
# 5   027-047-199     STRATA  1.725950e+11         17259506  CD-1 (265)
# 6   023-246-464     STRATA  6.141570e+11         61415705  CD-1 (297)
# 7   013-213-806       LAND  6.550200e+11         65502011        RS-1
# 8   030-461-413     STRATA  5.902180e+11         59021775  CD-1 (561)
# 9   029-010-951     STRATA  6.401820e+11         64018235  CD-1 (464)
# 10  018-918-263     STRATA  6.541850e+11         65418495        RM-4
# 11  011-776-498       LAND  4.069296e+10          4069296         C-2
# ...

# %%
# Distribution of number of houses built between 1900 and 2019

# %%
PLAN = data[data.EPS2945 == 'PLAN']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-177e0d768e31> in <module>
# ----> 1 PLAN = data[data.EPS2945 == 'PLAN']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'EPS2945'

# %%
data.assignment_property == 'LAND'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-7061ec04f268> in <module>
# ----> 1 data.assignment_property == 'LAND'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'assignment_property'

# %%
plt.plot(FOLIO, PLAN)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-431529e8ab3d> in <module>
# ----> 1 plt.plot(FOLIO, PLAN)
#       2 plt.show()
#
# NameError: name 'FOLIO' is not defined

# %%
data = pd.read_csv('alm_hardware.csv')

# %%
data
# Out:
#            Asset tag Model category  \
# 0            4NS6SY2      Computers
# 1         VF00013017      Computers
# 2         VFNA010027      Computers
# 3         VFNA016451      Computers
# 4         VFNA016519      Computers
# ..               ...            ...
# 98        VFNA020142      Computers
# 99        VFNA020143      Computers
# 100       VFNA020144      Computers
# 101       VFNA020179      Computers
# 102  VFSNA0000000532      Computers
#
#                                           Display name  Assigned to  \
# 0             4NS6SY2 - Dell Precision 5820 (Graphics)          NaN
# 1        VF00013017 - Apple MacBook Pro MacBookPro15,1          NaN
# 2           VFNA010027 - Dell XPS (Notebook) 13 (9365)          NaN
# 3                      VFNA016451 - Dell Latitude 7490          NaN
# 4                      VFNA016519 - Dell Latitude 7490          NaN
# ..                                                 ...          ...
# ...

# %%
plt.plot(Cost, State)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-7a7ac36f3136> in <module>
# ----> 1 plt.plot(Cost, State)
#       2 plt.show()
#
# NameError: name 'Cost' is not defined
